# %%
import pickle
import numpy as np
import pandas as pd

# %%
loaded_model = pickle.load(open("finalized_model_linear.sav", "rb"))

sample = pd.DataFrame({
    "bedrooms": [4],
    "bathrooms": [3],
    "square_feet": [2000],
    "lot_size_sqft": [3000],
    "property_condition":[1],
    "distance_to_city_center_km": [5],
})

prediction = loaded_model.predict(sample)

print(prediction)
# Out:
# [952026.59765482]

# %%
print(loaded_model.n_features_in_)
print(loaded_model.feature_names_in_)
# Out:
# 6
# ['bedrooms' 'bathrooms' 'square_feet' 'lot_size_sqft' 'property_condition'
#  'distance_to_city_center_km']

# %%
prediction
# Out:
# array([952026.59765482])
