# %%
import pickle
import numpy as np
import pandas as pd

# %%
loaded_model = pickle.load(open("finalized_model_linear.sav", "rb"))

sample = pd.DataFrame({
    "bedrooms": [4],
    "bathrooms": [3],
    "square_feet": [2000],
    "lot_size_sqft": [3000],
    "year_built": [2018],
    "garage_spaces": [2],
    "distance_to_city_center_km": [5],
    "crime_rate_index": [25],
    "nearby_school_rating": [8],
    "days_on_market": [30]
})

prediction = loaded_model.predict(sample)

print(prediction)
# Out:
# [950558.79501369]

# %%
print(loaded_model.n_features_in_)
print(loaded_model.feature_names_in_)
# Out:
# 10
# ['bedrooms' 'bathrooms' 'square_feet' 'lot_size_sqft' 'year_built'
#  'garage_spaces' 'distance_to_city_center_km' 'crime_rate_index'
#  'nearby_school_rating' 'days_on_market']

# %%
prediction
# Out:
# array([950558.79501369])
